# %%
import pandas as pd

# %%
df1 = pd.read_csv('../output/GDP/table.csv')
df2 = pd.read_csv('../output/GradPer/table.csv')
df3 = pd.read_csv('../output/presidential/table.csv')

df1['Region'] = df1['Region'].str.strip()
df2['Region'] = df2['Region'].str.strip()
df3['Region'] = df3['Region'].str.strip()

# %%
df = df1.merge(df2, on='Region', how='outer').reset_index(drop=True).merge(df3, on='Region', how='outer').reset_index(drop=True)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#        Region   GDP_2011   GDP_2015   GDP_2019 GP_2011  GP_2015 GP_2019  \
# 0     Alabama   150330.0   206341.0   234054.0      75     87.1    90.6
# 1      Alaska    44702.0    51560.0    55759.0      70     76.1    79.1
# 2     Arizona   227098.0   294170.0   372522.0      76     79.5    77.3
# 3    Arkansas    91496.0   124792.0   135225.0      84     87.0    88.8
# 4  California  1735360.0  2496710.0  3183251.0      79     83.0    84.3
#
#    demVotes_2012  gopVotes_2012  otherVotes_2012  totalVotes_2012  \
# 0       795696.0      1255925.0          22717.0        2074338.0
# 1       122640.0       164676.0          13179.0         300495.0
# 2      1025232.0      1233654.0          40368.0        2299254.0
# 3       394409.0       647744.0          27315.0        1069468.0
# 4      7854285.0      4839958.0         344304.0       13038547.0
#
#    demVotes_2016  gopVotes_2016  otherVotes_2016  totalVotes_2016  \
# ...
